# %% [markdown]
# Macros

# %% [markdown]
# Libraries and plotting functions

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

def rot_mat(angle):
  return np.array([[np.cos(angle),-np.sin(angle)],
                   [np.sin(angle),np.cos(angle)]])

def show_plot(title, x_label, x_vals, y_label, y_vals, symbol):
  plt.title(title)
  plt.xlabel(x_label)
  plt.ylabel(y_label)
  plt.plot(x_vals,y_vals,symbol)
  plt.show()
  return None

def multi_plot(title, x_label, x_vals, y_label, y_vals, symbol):
  plt.title(title)
  plt.xlabel(x_label)
  plt.ylabel(y_label)
  for i in range(symbol.size):
    plt.plot(x_vals,y_vals[i,:],symbol[i])
  plt.show()
  return None

# %% [markdown]
# The Standard Colatz Algorithm

# %%
# Returns array that specifies Collatz path
def collatz(p, end=1):
  def collatz_step(p,Max):
    if (int(p) & 1):
      p = 3*p+1
      return int(p), True, int(max(Max,p))
    return int(p/2), False, int(Max)  # True = odd, False = even

  x = p
  step = False
  path = np.array([])
  Max = p

  while (x != 1 and x != end):
    x,step,Max  = collatz_step(x,Max)
    path        = np.append(path, int(step))

  return path.astype(int), Max

# %% [markdown]
# The Layered Algorithm

# %%
# def wrapper_step(p,show_ups=True,print_all=False):
#   # each step to simplify core code.
#   # It's dirty, but the purpose is to display, not optimize
#   def step_layer_up(R,K,path,Max,show_ups):
#     if (int(R) & 1):  # if we are on an odd number
#       R = 3*R + 1     # do 3x+1
#       K += 1          # and move up a layer
#       if (show_ups): path = np.append(path, 3)
#       if(print_all): print(int(R))
#     return int(R),int(K),path, max(Max,int(R))
#   def step_half(R, path):
#     if (R != 0):
#       R /= 2        # always /2
#       path = np.append(path, 0)
#       if(print_all): print(int(R))
#     return int(R), path
#   def step_add_3k(x,R,K,path,Max):
#     if (int(x) & 1):
#       power = 1
#       for i in range(K):  # didn't use 3**K for accuracy
#         power *= 3
#       R += power  # add 3^K to R iff the current bit is 1
#       path = np.append(path, 1)
#       if(print_all): print(int(R))
#     return int(x),int(R),int(K),path, max(Max,int(R))
#   def step_next_digit(x):
#     return int(x >> 1)

#   # initialize everything
#   x = p
#   R = 0
#   K = 0
#   path = np.array([])
#   Max = p
#   if(print_all): print('Start Wrapper at: ',int(R))

#   # The algorithm
#   while (x != 0):
#     R,K,path,Max    = step_layer_up(R,K,path,Max,show_ups)
#     R,path          = step_half(R,path)
#     x,R,K,path,Max  = step_add_3k(x,R,K,path,Max)
#     x               = step_next_digit(x)

#   return int(R), path.astype(int), Max

def threeToThe(K):
  power = 1
  for i in range(K):
    power *= 3
  return int(power)

def wrapper_step(p,show_ups=True,print_all=False):
  # initialize everything
  x = p
  R = 0
  K = 0
  path = np.array([])
  Max = p

  # The algorithm
  while (x != 0):
    if (int(R) & 1):  # if we are on an odd number
      R = 3*R + 1       # do 3x+1
      Max = max(Max,int(R))
      K += 1            # and move up a layer
      if (show_ups): path = np.append(path, 3)
      if (print_all): print(int(R))
    R /= 2            # always /2
    if (print_all): print(int(R))
    if (int(x) & 1):
      R += threeToThe(K)  # add 3^K to R iff the current bit is 1
      Max = max(Max,int(R))
      path = np.append(path, 1)
      if (print_all): print(int(R))
    else:
      path = np.append(path, 0)
    x = int(x >> 1)

  return int(R), path.astype(int), Max

# def wrapper_step(p,show_ups=True,print_all=False):
#   # initialize everything
#   x = p # the bit vector is the number in binary
#   R = 0 # R encodes the path we've already taken
#   K = 0 # Layer number

#   # The algorithm
#   while (x != 0):
#     if (int(R) & 1):    # if R is an odd number
#       R = 3*R + 1         # do 3R+1
#       K += 1              # and move up a layer
#     R /= 2              # always R/2
#     if (int(x) & 1):    # if the least significant bit is 1
#       R += threeToThe(K)  # add 3^K to R
#     x = int(x >> 1)     # move to the next bit

#   return int(R),np.array([]), max(int(p),int(R))

# %% [markdown]
# A function which compares the sizes of the maximum intermediate values used

# %%
def max_ratio(n):
  R, path, Wrap_Max = wrapper_step(n)
  path, Old_Max = collatz(n,R)
  return float(Wrap_Max)/float(Old_Max)

# %% [markdown]
# Graphs comparing the maximum stored values in each method

# %%
def graph_path_maxes(n, layer='r-', old="b-"):
  title = 'Comparing Maxes of The Methods by Value'
  x_axis_label = 'Input p'
  x_vals = np.transpose(np.array(range(1,n,1)))
  y_axis_label = 'Max number stored'
  y_vals=0
  plot_symbols = np.array([layer,old])

  wrap_maxes  = np.array([])
  old_maxes   = np.array([])

  for i in range(1,n,1):
    R, path, Wrap_Max = wrapper_step(i)
    wrap_maxes = np.append(wrap_maxes, Wrap_Max)
    path, Old_Max = collatz(i,R)
    old_maxes = np.append(old_maxes, Old_Max)

  y_vals = np.array([wrap_maxes.astype(int),
                     old_maxes.astype(int)])

  multi_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, plot_symbols)
  return

def graph_max_ratios(n, symbol = 'g.'):
  title = 'Comparing New/Old Maxes by Percent'
  x_axis_label = 'Input p'
  x_vals = np.transpose(np.array(range(1,n,1)))
  y_axis_label = 'Ratio of Maxes: New / Old'
  y_vals  = np.array([])

  for i in range(1,n,1):
    y_vals = np.append(y_vals, max_ratio(i))

  show_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, symbol)
  return

# %% [markdown]
# Count how many steps it takes to reach end

# %%
def count_collatz(p,end=1):
  path,Max = collatz(p, end)
  odds = np.count_nonzero(path)
  evens = path.size - odds
  return odds,evens

def count_layer_single(p):
  R,path,Max = wrapper_step(p,False,False)
  odds = np.count_nonzero(path)
  evens = path.size - odds
  return R, odds,evens

def count_layer(p):
  odds,evens = 0,0
  x=p
  while (x != 1):
    x,_odds_,_evens_ = count_layer_single(x)
    odds += _odds_
    evens += _evens_
  return odds,evens

# %% [markdown]
# Graph the number of steps needed to resolve each number

# %%
def graph_collatz(n,show_evens=False,symbol='b.'):
  title = 'Collatz Numbers for various inputs'
  if (not(show_evens)): title += ' Excluding Even Steps'
  x_axis_label = 'Input p'
  x_vals = np.transpose(np.array(range(1,n,1)))
  y_axis_label = 'Steps to 1'
  y_vals = np.array([])

  for i in range(1,n,1):
    odds, evens = count_collatz(i)
    y_vals = np.append(y_vals, odds + evens*int(show_evens))

  show_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, symbol)
  return

def graph_compare_step_count(n, show_evens=True,scale=False, layer='r.',old="b."):
  title = 'Comparing New and Old Step Counts'
  if (not(show_evens)): title += ' Excluding Even Steps'
  x_axis_label = 'Input p'
  x_vals = np.transpose(np.array(range(1,n,1)))
  y_axis_label = 'Steps to 1'
  y_vals=0
  plot_symbols = np.array([layer,old])

  wrap_counts = np.array([])
  old_counts  = np.array([])

  for i in range(1,n,1):
    wrap_odds  = 0
    wrap_evens = 0
    old_odds   = 0
    old_evens  = 0

    _w_odds_,_w_evens_ = count_layer(i)
    wrap_odds += _w_odds_
    wrap_evens += _w_evens_
    _c_odds_,_c_evens_ = count_collatz(i)
    old_odds += _c_odds_
    old_evens += _c_evens_

    wrap_counts = np.append(wrap_counts, wrap_odds + wrap_evens*int(show_evens))
    old_counts  = np.append(old_counts, old_odds + old_evens*int(show_evens))

  y_vals = np.array([wrap_counts, old_counts])

  if(scale):
    x_vals = np.log2(x_vals)

  multi_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, plot_symbols)
  return

# %% [markdown]
# Transform Collatz Numbers To Grid

# %%
trans = np.array([[1,0.57],
                  [0.36,1]])
inv_trans = np.linalg.inv(trans)

def norm_collatz(n,angle = 0, scale=1, A=0,B=0,C=0,D=0,dx=0,dy=0, show_evens=False):
  x_vals = np.transpose(np.array(range(1,n,1)))
  y_vals = np.array([])

  for i in range(1,n,1):
    odds, evens = count_collatz(i)
    y_vals = np.append(y_vals, odds + evens*int(show_evens))

  x_vals = 10*np.log(x_vals)

  old_vars = np.array([x_vals,y_vals])

  #adj_trans = inv_trans + np.array([[A,B],[C,D]])
  adj_trans = rot_mat(2*np.pi*angle)
  new_vars = np.matmul(adj_trans,old_vars)
  x_vals = new_vars[0,:]*(scale)
  y_vals = new_vars[1,:]*(1+dy)

  return x_vals,y_vals

def find_buddies(p,end=300):  # buddies are numbers of similar size with similar Collatz numbers
  x,y = norm_collatz(end)
  results = np.array([])
  for i in range(x.size):
    if(int(x[i]) == int(x[p]) and int(y[i]) == int(y[p])):
      results = np.append(results, int(i))
  return results

# %%
def graph_collatz(n, show_evens=False,scale=False, step=1, symbol='b.'):
  title = 'Collatz Numbers for various inputs'
  if (not(show_evens)): title += ' Excluding Even Steps'
  x_axis_label = 'Input p = 2^x'
  x_vals = np.transpose(np.array(range(1,n,step)))
  y_axis_label = 'Steps to 1'
  y_vals = np.array([])

  for i in range(1,n,step):
    odds, evens = count_collatz(i)
    y_vals = np.append(y_vals, odds + evens*int(show_evens))

  if(scale):
    x_vals = np.log2(x_vals)
  show_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, symbol)
  return

def graph_normed_collatz(n, angle=0, scale=1, A=0,B=0,C=0,D=0,dx=0,dy=0, show_evens=False,symbol='b.'):
  title = 'Collatz Numbers for various inputs'
  if (not(show_evens)): title += ' Excluding Even Steps'
  x_axis_label = 'Input p'

  y_axis_label = 'Adjusted Steps to 1'
  x_vals,y_vals = norm_collatz(n,angle, scale, A,B,C,D,dx,dy,show_evens)

  x_rounded = np.round(x_vals)
  y_rounded = np.round(y_vals)

  x_error = x_rounded-x_vals
  y_error = y_rounded-y_vals
  #print('Mean error with\t',A,',\t',B,', ',C,', ',D,', ',' is ',x_error.mean(),', ',y_error.mean())

  show_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, symbol)
  show_plot('rounded', x_axis_label, x_rounded, y_axis_label, y_rounded, symbol)
  show_plot('error', 'x-error', x_error, 'y-error', y_error, symbol)
  return A,B,C,D,dx,dy, np.std(x_error),np.std(y_error)

# %%
def fix_error(tests):
  A,B,C,D,dx,dy,x,y = graph_normed_collatz(300,2.7,0.174,-1.404,0.4,0.36,0.31)
  size = 2.0
  for i in range(tests):
    _A,_B,_C,_D,_dx,_dy,_x,_y = graph_normed_collatz(300,
                       A+(size*(random.random()-0.5)), # A
                       B+(size*(random.random()-0.5)), # B
                       C+(size*(random.random()-0.5)), # C
                       D+(size*(random.random()-0.5)), # D
                       dx+(size*(random.random()-dx)), # dx
                       dy+(size*(random.random()-dy))) # dy
    if(abs(_x) < 0.26 and abs(_y) < 0.23):
      print(_A,', ',_B,', ',_C,', ',_D,', ',_dx,', ',_dy,', ',_x,', ',_y)
      x = _x
      dx = _dx
      A=_A
      B=_B
      y = _y
      dy = _dy
      C=_C
      D=_D
    #size *= 0.99
  return A,B,C,D,dx,dy,x,y

# %% [markdown]
# My sequence

# %%
def Wrapper_Sequence(n, showPath=False):
  for i in range(n):
    if (showPath): print(f'{i}: {wrapper_step(i)}')
    else: print(f'{i}: {wrapper_step(i)[0]}')
  return

#sequence A216851

# %%
def norm_wrap(p):
  x = np.array(range(1,p,1))
  y = np.array([])
  for i in x:
    y = np.append(y, wrapper_step(i)[0])
  x = np.log2(x)
  y = np.log((y+1)/2)/np.log(3)
  x = x - y
  #y = y + np.ones(y.shape)

  vals = np.array([x,y])
  angle = 0#0.785
  trans = np.matmul(np.array([[np.cos(angle),-np.sin(angle)],[np.sin(angle),np.cos(angle)]]),
                    np.array([[1,0],
                              [0,1]]))
  result = np.matmul(trans,vals)
  return result[0],result[1]

def graph_norm_wrap(n,norm=True,symbol='r.'):
  title = 'Wrapper Numbers for various inputs'
  x_axis_label = 'Input p'

  if(norm):
    y_axis_label = 'Normed Level'
    x_vals,y_vals = norm_wrap(n)

    x_rounded = np.ceil(x_vals)
    y_rounded = np.ceil(y_vals)

    x_error = x_rounded-x_vals
    y_error = y_rounded-y_vals
    #print('Mean error with\t',A,',\t',B,', ',C,', ',D,', ',' is ',x_error.mean(),', ',y_error.mean())

    show_plot(title, x_axis_label, x_vals, y_axis_label, y_vals, symbol)
    show_plot('rounded', x_axis_label, x_rounded, y_axis_label, y_rounded, symbol)
    show_plot('error', 'x-error', x_error, 'y-error', y_error, symbol)
    return np.std(x_error),np.std(y_error)

  y_axis_label = 'Output of Wrapper'
  x = np.array(range(1,n,1))
  y = np.array([])
  for i in x:
    y = np.append(y, wrapper_step(i)[0])
  show_plot(title, x_axis_label, x, y_axis_label, y, symbol)
  return

# %% [markdown]
# Test Functions

# %%
# print(collatz(6833941,44))
# print(wrapper_step(9663*8,True, True))
# graph_path_maxes(300)
# graph_max_ratios(5000)
# print(count_collatz(27))
# print(count_layer(31))
# graph_compare_step_count(5000)
# graph_compare_step_count(20000,False,True)
# graph_collatz(10000,False,True) # 1 min for 100 000,False,True
# graph_normed_collatz(5000)  #0.1969,0.451
# print(fix_error(1000))
Wrapper_Sequence(100, True)
# graph_norm_wrap(20000,False)
# print(find_buddies(95))
# Out:
# 0: (0, array([], dtype=int64), 0)
# 1: (1, array([1]), 1)
# 2: (1, array([0, 1]), 2)
# 3: (5, array([1, 3, 1]), 5)
# 4: (1, array([0, 0, 1]), 4)
# 5: (4, array([1, 3, 0, 1]), 5)
# 6: (5, array([0, 1, 3, 1]), 6)
# 7: (17, array([1, 3, 1, 3, 1]), 17)
# 8: (1, array([0, 0, 0, 1]), 8)
# 9: (11, array([1, 3, 0, 0, 3, 1]), 11)
# 10: (4, array([0, 1, 3, 0, 1]), 10)
# 11: (13, array([1, 3, 1, 3, 0, 1]), 16)
# 12: (5, array([0, 0, 1, 3, 1]), 12)
# 13: (5, array([1, 3, 0, 1, 1]), 13)
# 14: (17, array([0, 1, 3, 1, 3, 1]), 17)
# 15: (53, array([1, 3, 1, 3, 1, 3, 1]), 53)
# 16: (1, array([0, 0, 0, 0, 1]), 16)
# 17: (10, array([1, 3, 0, 0, 3, 0, 1]), 17)
# 18: (11, array([0, 1, 3, 0, 0, 3, 1]), 18)
# 19: (11, array([1, 3, 1, 3, 0, 0, 1]), 19)
# 20: (4, array([0, 0, 1, 3, 0, 1]), 20)
# 21: (4, array([1, 3, 0, 1, 0, 1]), 21)
# 22: (13, array([0, 1, 3, 1, 3, 0, 1]), 22)
# 23: (40, array([1, 3, 1, 3, 1, 3, 0, 1]), 52)
# 24: (5, array([0, 0, 0, 1, 3, 1]), 24)
# ...
